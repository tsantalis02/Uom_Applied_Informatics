# %%
import pandas as pd

# %%
letter_recognition_data = pd.read_csv("F:\Μαθήματα_Στέργιος\Ανακάλυψη_Γνώσης_Από_Βάσεις_Δεδομένων\PP1\pp1\letter-recognition.csv")

# %%
letter_recognition_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   xbox    20000 non-null  int64
#  1   ybox    20000 non-null  int64
#  2   width   20000 non-null  int64
#  3   high    20000 non-null  int64
#  4   onpix   20000 non-null  int64
#  5   xbar    20000 non-null  int64
#  6   ybar    20000 non-null  int64
#  7   x2bar   20000 non-null  int64
#  8   y2bar   20000 non-null  int64
#  9   xybar   20000 non-null  int64
#  10  x2ybar  20000 non-null  int64
#  11  xy2bar  20000 non-null  int64
#  12  xege    20000 non-null  int64
#  13  xegvy   20000 non-null  int64
#  14  yege    20000 non-null  int64
#  15  yegvx   20000 non-null  int64
#  16  class   20000 non-null  object
# dtypes: int64(16), object(1)
# memory usage: 2.6+ MB

# %%
df = pd.DataFrame(letter_recognition_data)

# %%
df
# Out:
#        xbox  ybox  width  high  onpix  xbar  ybar  x2bar  y2bar  xybar  \
# 0         2     8      3     5      1     8    13      0      6      6
# 1         5    12      3     7      2    10     5      5      4     13
# 2         4    11      6     8      6    10     6      2      6     10
# 3         7    11      6     6      3     5     9      4      6      4
# 4         2     1      3     1      1     8     6      6      6      6
# ...     ...   ...    ...   ...    ...   ...   ...    ...    ...    ...
# 19995     2     2      3     3      2     7     7      7      6      6
# 19996     7    10      8     8      4     4     8      6      9     12
# 19997     6     9      6     7      5     6    11      3      7     11
# 19998     2     3      4     2      1     8     7      2      6     10
# 19999     4     9      6     6      2     9     5      3      1      8
#
#        x2ybar  xy2bar  xege  xegvy  yege  yegvx class
# 0          10       8     0      8     0      8     T
# ...

# %%
from sklearn import preprocessing

# %%
del_column = df['class']
del df['class']
d = preprocessing.normalize(df)
norm_df = pd.DataFrame(d)
norm_df
# Out:
#              0         1         2         3         4         5         6   \
# 0      0.075593  0.302372  0.113389  0.188982  0.037796  0.302372  0.491354
# 1      0.172516  0.414039  0.103510  0.241523  0.069007  0.345033  0.172516
# 2      0.145575  0.400331  0.218362  0.291150  0.218362  0.363937  0.218362
# 3      0.256460  0.403009  0.219823  0.219823  0.109911  0.183186  0.329734
# 4      0.088999  0.044499  0.133498  0.044499  0.044499  0.355995  0.266996
# ...         ...       ...       ...       ...       ...       ...       ...
# 19995  0.096787  0.096787  0.145180  0.145180  0.096787  0.338754  0.338754
# 19996  0.218430  0.312043  0.249635  0.249635  0.124817  0.124817  0.249635
# 19997  0.207390  0.311086  0.207390  0.241955  0.172825  0.207390  0.380216
# 19998  0.084667  0.127000  0.169334  0.084667  0.042333  0.338667  0.296334
# 19999  0.172292  0.387657  0.258438  0.258438  0.086146  0.387657  0.215365
#
# ...

# %%
norm_df['class'] = del_column
norm_df.columns = letter_recognition_data.columns
norm_df
# Out:
#            xbox      ybox     width      high     onpix      xbar      ybar  \
# 0      0.075593  0.302372  0.113389  0.188982  0.037796  0.302372  0.491354
# 1      0.172516  0.414039  0.103510  0.241523  0.069007  0.345033  0.172516
# 2      0.145575  0.400331  0.218362  0.291150  0.218362  0.363937  0.218362
# 3      0.256460  0.403009  0.219823  0.219823  0.109911  0.183186  0.329734
# 4      0.088999  0.044499  0.133498  0.044499  0.044499  0.355995  0.266996
# ...         ...       ...       ...       ...       ...       ...       ...
# 19995  0.096787  0.096787  0.145180  0.145180  0.096787  0.338754  0.338754
# 19996  0.218430  0.312043  0.249635  0.249635  0.124817  0.124817  0.249635
# 19997  0.207390  0.311086  0.207390  0.241955  0.172825  0.207390  0.380216
# 19998  0.084667  0.127000  0.169334  0.084667  0.042333  0.338667  0.296334
# 19999  0.172292  0.387657  0.258438  0.258438  0.086146  0.387657  0.215365
#
# ...

# %%
norm_df.to_csv('letter-recognition.csv', index = False)

# %%
iris_data = pd.read_csv('F:\Μαθήματα_Στέργιος\Ανακάλυψη_Γνώσης_Από_Βάσεις_Δεδομένων\PP1\pp1\iris.csv')
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sepall  150 non-null    float64
#  1   sepalw  150 non-null    float64
#  2   petall  150 non-null    float64
#  3   petalw  150 non-null    float64
#  4   class   150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df2 = pd.DataFrame(iris_data)
df2
# Out:
#      sepall  sepalw  petall  petalw           class
# 0       5.1     3.5     1.4     0.2     Iris-setosa
# 1       4.9     3.0     1.4     0.2     Iris-setosa
# 2       4.7     3.2     1.3     0.2     Iris-setosa
# 3       4.6     3.1     1.5     0.2     Iris-setosa
# 4       5.0     3.6     1.4     0.2     Iris-setosa
# ..      ...     ...     ...     ...             ...
# 145     6.7     3.0     5.2     2.3  Iris-virginica
# 146     6.3     2.5     5.0     1.9  Iris-virginica
# 147     6.5     3.0     5.2     2.0  Iris-virginica
# 148     6.2     3.4     5.4     2.3  Iris-virginica
# 149     5.9     3.0     5.1     1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
del_column2 = df2['class']
del df2['class']
d2 = preprocessing.normalize(df2)
norm_df2 = pd.DataFrame(d2)
norm_df2
# Out:
#             0         1         2         3
# 0    0.803773  0.551609  0.220644  0.031521
# 1    0.828133  0.507020  0.236609  0.033801
# 2    0.805333  0.548312  0.222752  0.034269
# 3    0.800030  0.539151  0.260879  0.034784
# 4    0.790965  0.569495  0.221470  0.031639
# ..        ...       ...       ...       ...
# 145  0.721557  0.323085  0.560015  0.247699
# 146  0.729654  0.289545  0.579090  0.220054
# 147  0.716539  0.330710  0.573231  0.220474
# 148  0.674671  0.369981  0.587616  0.250281
# 149  0.690259  0.350979  0.596665  0.210588
#
# [150 rows x 4 columns]

# %%
norm_df2['4'] = del_column2
norm_df2.columns = iris_data.columns
norm_df2
# Out:
#        sepall    sepalw    petall    petalw           class
# 0    0.803773  0.551609  0.220644  0.031521     Iris-setosa
# 1    0.828133  0.507020  0.236609  0.033801     Iris-setosa
# 2    0.805333  0.548312  0.222752  0.034269     Iris-setosa
# 3    0.800030  0.539151  0.260879  0.034784     Iris-setosa
# 4    0.790965  0.569495  0.221470  0.031639     Iris-setosa
# ..        ...       ...       ...       ...             ...
# 145  0.721557  0.323085  0.560015  0.247699  Iris-virginica
# 146  0.729654  0.289545  0.579090  0.220054  Iris-virginica
# 147  0.716539  0.330710  0.573231  0.220474  Iris-virginica
# 148  0.674671  0.369981  0.587616  0.250281  Iris-virginica
# 149  0.690259  0.350979  0.596665  0.210588  Iris-virginica
#
# [150 rows x 5 columns]

# %%
norm_df2.to_csv('iris.csv', index = False)

# %%
letter_recognition_data = pd.read_csv(r"C:\Users\UserA\Desktop\PP1_iis21125\letter-recognition.csv")
letter_recognition_data.info()
df3 = pd.DataFrame(letter_recognition_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   xbox    20000 non-null  float64
#  1   ybox    20000 non-null  float64
#  2   width   20000 non-null  float64
#  3   high    20000 non-null  float64
#  4   onpix   20000 non-null  float64
#  5   xbar    20000 non-null  float64
#  6   ybar    20000 non-null  float64
#  7   x2bar   20000 non-null  float64
#  8   y2bar   20000 non-null  float64
#  9   xybar   20000 non-null  float64
#  10  x2ybar  20000 non-null  float64
#  11  xy2bar  20000 non-null  float64
#  12  xege    20000 non-null  float64
#  13  xegvy   20000 non-null  float64
#  14  yege    20000 non-null  float64
#  15  yegvx   20000 non-null  float64
#  16  class   20000 non-null  object
# dtypes: float64(16), object(1)
# memory usage: 2.6+ MB

# %%
df3
# Out:
#            xbox      ybox     width      high     onpix      xbar      ybar  \
# 0      0.075593  0.302372  0.113389  0.188982  0.037796  0.302372  0.491354
# 1      0.172516  0.414039  0.103510  0.241523  0.069007  0.345033  0.172516
# 2      0.145575  0.400331  0.218362  0.291150  0.218362  0.363937  0.218362
# 3      0.256460  0.403009  0.219823  0.219823  0.109911  0.183186  0.329734
# 4      0.088999  0.044499  0.133498  0.044499  0.044499  0.355995  0.266996
# ...         ...       ...       ...       ...       ...       ...       ...
# 19995  0.096787  0.096787  0.145180  0.145180  0.096787  0.338754  0.338754
# 19996  0.218430  0.312043  0.249635  0.249635  0.124817  0.124817  0.249635
# 19997  0.207390  0.311086  0.207390  0.241955  0.172825  0.207390  0.380216
# 19998  0.084667  0.127000  0.169334  0.084667  0.042333  0.338667  0.296334
# 19999  0.172292  0.387657  0.258438  0.258438  0.086146  0.387657  0.215365
#
# ...

# %%
X = df3.drop(['class'], axis = 1)
y = df3['class'].values
y
# Out:
# array(['T', 'I', 'D', ..., 'T', 'S', 'A'], dtype=object)

# %%
from collections import Counter
from imblearn.under_sampling import EditedNearestNeighbours
k = 4
enn = EditedNearestNeighbours(n_neighbors = k)
X_res,y_res = enn.fit_resample(X,y)
print(X_res)
print('Resampled dataset after ENN shape %s' % Counter(y_res))
y_res
# Out:
#            xbox      ybox     width      high     onpix      xbar      ybar  \
# 0      0.056433  0.056433  0.169300  0.112867  0.056433  0.451466  0.112867
# 1      0.125000  0.291667  0.208333  0.208333  0.125000  0.500000  0.083333
# 2      0.138233  0.368621  0.230388  0.276465  0.138233  0.414698  0.092155
# 3      0.115857  0.057928  0.231714  0.115857  0.057928  0.463428  0.057928
# 4      0.139122  0.324617  0.231869  0.231869  0.139122  0.463739  0.185496
# ...         ...       ...       ...       ...       ...       ...       ...
# 17000  0.149592  0.224387  0.224387  0.149592  0.149592  0.336581  0.411377
# 17001  0.086793  0.043396  0.086793  0.043396  0.043396  0.347170  0.303774
# 17002  0.102240  0.306719  0.136320  0.238559  0.068160  0.238559  0.238559
# 17003  0.162564  0.325128  0.195077  0.260102  0.097538  0.227590  0.227590
# 17004  0.083333  0.208333  0.125000  0.166667  0.083333  0.291667  0.291667
#
# ...

# %%
X_res
# Out:
#            xbox      ybox     width      high     onpix      xbar      ybar  \
# 0      0.056433  0.056433  0.169300  0.112867  0.056433  0.451466  0.112867
# 1      0.125000  0.291667  0.208333  0.208333  0.125000  0.500000  0.083333
# 2      0.138233  0.368621  0.230388  0.276465  0.138233  0.414698  0.092155
# 3      0.115857  0.057928  0.231714  0.115857  0.057928  0.463428  0.057928
# 4      0.139122  0.324617  0.231869  0.231869  0.139122  0.463739  0.185496
# ...         ...       ...       ...       ...       ...       ...       ...
# 17000  0.149592  0.224387  0.224387  0.149592  0.149592  0.336581  0.411377
# 17001  0.086793  0.043396  0.086793  0.043396  0.043396  0.347170  0.303774
# 17002  0.102240  0.306719  0.136320  0.238559  0.068160  0.238559  0.238559
# 17003  0.162564  0.325128  0.195077  0.260102  0.097538  0.227590  0.227590
# 17004  0.083333  0.208333  0.125000  0.166667  0.083333  0.291667  0.291667
#
# ...

# %%
X_res['class'] = y_res
X_res
# Out:
#            xbox      ybox     width      high     onpix      xbar      ybar  \
# 0      0.056433  0.056433  0.169300  0.112867  0.056433  0.451466  0.112867
# 1      0.125000  0.291667  0.208333  0.208333  0.125000  0.500000  0.083333
# 2      0.138233  0.368621  0.230388  0.276465  0.138233  0.414698  0.092155
# 3      0.115857  0.057928  0.231714  0.115857  0.057928  0.463428  0.057928
# 4      0.139122  0.324617  0.231869  0.231869  0.139122  0.463739  0.185496
# ...         ...       ...       ...       ...       ...       ...       ...
# 17000  0.149592  0.224387  0.224387  0.149592  0.149592  0.336581  0.411377
# 17001  0.086793  0.043396  0.086793  0.043396  0.043396  0.347170  0.303774
# 17002  0.102240  0.306719  0.136320  0.238559  0.068160  0.238559  0.238559
# 17003  0.162564  0.325128  0.195077  0.260102  0.097538  0.227590  0.227590
# 17004  0.083333  0.208333  0.125000  0.166667  0.083333  0.291667  0.291667
#
# ...

# %%
df3
# Out:
#            xbox      ybox     width      high     onpix      xbar      ybar  \
# 0      0.075593  0.302372  0.113389  0.188982  0.037796  0.302372  0.491354
# 1      0.172516  0.414039  0.103510  0.241523  0.069007  0.345033  0.172516
# 2      0.145575  0.400331  0.218362  0.291150  0.218362  0.363937  0.218362
# 3      0.256460  0.403009  0.219823  0.219823  0.109911  0.183186  0.329734
# 4      0.088999  0.044499  0.133498  0.044499  0.044499  0.355995  0.266996
# ...         ...       ...       ...       ...       ...       ...       ...
# 19995  0.096787  0.096787  0.145180  0.145180  0.096787  0.338754  0.338754
# 19996  0.218430  0.312043  0.249635  0.249635  0.124817  0.124817  0.249635
# 19997  0.207390  0.311086  0.207390  0.241955  0.172825  0.207390  0.380216
# 19998  0.084667  0.127000  0.169334  0.084667  0.042333  0.338667  0.296334
# 19999  0.172292  0.387657  0.258438  0.258438  0.086146  0.387657  0.215365
#
# ...

# %%
from collections import Counter  
from imblearn.under_sampling import CondensedNearestNeighbour  

letter_recognition_data = pd.read_csv(r"C:\Users\UserA\Desktop\PP1_iis21125\letter-recognition.csv")
df4 = pd.DataFrame(letter_recognition_data)
X = df4.drop(['class'], axis = 1)
y = df4['class'].values
  

print('Original dataset shape %s' % Counter(y))  
 
#k=4
#cnn = CondensedNearestNeighbour(n_neighbors=k)  
cnn = CondensedNearestNeighbour()

X_res, y_res = cnn.fit_resample(X, y)  

print('Resampled dataset shape %s' % Counter(y_res))
# Out:
# Original dataset shape Counter({'U': 813, 'D': 805, 'P': 803, 'T': 796, 'M': 792, 'A': 789, 'X': 787, 'Y': 786, 'N': 783, 'Q': 783, 'F': 775, 'G': 773, 'E': 768, 'B': 766, 'V': 764, 'L': 761, 'R': 758, 'I': 755, 'O': 753, 'W': 752, 'S': 748, 'J': 747, 'K': 739, 'C': 736, 'H': 734, 'Z': 734})
# Resampled dataset shape Counter({'H': 734, 'K': 145, 'D': 116, 'R': 115, 'B': 84, 'N': 75, 'G': 74, 'O': 67, 'U': 65, 'X': 64, 'E': 62, 'S': 51, 'P': 49, 'Q': 49, 'M': 46, 'F': 45, 'C': 40, 'Y': 37, 'J': 32, 'L': 30, 'A': 29, 'W': 29, 'T': 26, 'Z': 26, 'V': 25, 'I': 22})

# %%
X_res['class']=y_res
X_res
# Out:
#           xbox      ybox     width      high     onpix      xbar      ybar  \
# 0     0.088388  0.309359  0.176777  0.220971  0.132583  0.486136  0.132583
# 1     0.056433  0.056433  0.169300  0.112867  0.056433  0.451466  0.112867
# 2     0.152894  0.152894  0.254824  0.203859  0.050965  0.356753  0.305788
# 3     0.215666  0.323498  0.287554  0.287554  0.287554  0.287554  0.251610
# 4     0.195366  0.390732  0.273513  0.312586  0.195366  0.312586  0.117220
# ...        ...       ...       ...       ...       ...       ...       ...
# 2132  0.207390  0.380216  0.276520  0.276520  0.241955  0.345651  0.172825
# 2133  0.184302  0.331744  0.184302  0.147442  0.110581  0.184302  0.294884
# 2134  0.151078  0.151078  0.226617  0.226617  0.113308  0.453234  0.151078
# 2135  0.239255  0.375972  0.239255  0.205076  0.136717  0.273434  0.205076
# 2136  0.254128  0.412959  0.285894  0.222362  0.190596  0.158830  0.285894
#
# ...

# %%
from matplotlib import pyplot
from numpy import where
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.under_sampling import CondensedNearestNeighbour

#define dataset
X, y = make_classification(n_samples=10000, n_features=2, n_redundant=0,n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=2)

#summarize class distribution 
counter = Counter(y)
print(counter)

#define the undersampling method
undersample = CondensedNearestNeighbour(n_neighbors=1)

#transform the dataset
X, y = undersample.fit_resample(X, y)

#summarize the new class distribution after CNN
counter = Counter(y)
print(counter)

#scatter plot of examples by class label
for label, _ in counter.items():
    row_ix = where(y == label)[0]
    pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
# Out:
# Counter({0: 9900, 1: 100})
# Counter({0: 115, 1: 100})
